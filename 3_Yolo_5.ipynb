# %% [markdown]
# Let´s use a requirements-file this time!

# %%
# !pip install -r requirements_yolov5.txt # install dependencies
# Out:
# Looking in indexes: https://nexus.iisys.de/repository/ki-awz-pypi-group/simple, https://pypi.org/simple
# Requirement already satisfied: gitpython>=3.1.30 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 5)) (3.1.45)
# Requirement already satisfied: matplotlib>=3.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 6)) (3.10.6)
# Requirement already satisfied: numpy>=1.23.5 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 7)) (2.2.6)
# Collecting opencv-python>=4.1.1 (from -r requirements_yolov5.txt (line 8))
#   Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: pillow>=10.3.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 9)) (11.3.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 10)) (7.0.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 12)) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 13)) (1.16.1)
# Collecting thop>=0.1.1 (from -r requirements_yolov5.txt (line 14))
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 15)) (2.8.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 16)) (0.23.0+cu128)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 17)) (4.67.1)
# Collecting ultralytics>=8.2.64 (from -r requirements_yolov5.txt (line 18))
#   Downloading ultralytics-8.3.218-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 27)) (2.3.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 28)) (0.13.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 42)) (25.0)
# Requirement already satisfied: setuptools>=70.0.0 in /opt/conda/lib/python3.12/site-packages (from -r requirements_yolov5.txt (line 43)) (80.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.12/site-packages (from gitpython>=3.1.30->-r requirements_yolov5.txt (line 5)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements_yolov5.txt (line 5)) (5.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements_yolov5.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements_yolov5.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements_yolov5.txt (line 6)) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements_yolov5.txt (line 6)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements_yolov5.txt (line 6)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements_yolov5.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.2->-r requirements_yolov5.txt (line 12)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.2->-r requirements_yolov5.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.2->-r requirements_yolov5.txt (line 12)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests>=2.32.2->-r requirements_yolov5.txt (line 12)) (2025.8.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (3.5)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /opt/conda/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (3.4.0)
# Collecting polars (from ultralytics>=8.2.64->-r requirements_yolov5.txt (line 18))
#   Using cached polars-1.34.0-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics>=8.2.64->-r requirements_yolov5.txt (line 18))
#   Using cached ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas>=1.1.4->-r requirements_yolov5.txt (line 27)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=1.1.4->-r requirements_yolov5.txt (line 27)) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements_yolov5.txt (line 6)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->-r requirements_yolov5.txt (line 15)) (3.0.2)
# Collecting polars-runtime-32==1.34.0 (from polars->ultralytics>=8.2.64->-r requirements_yolov5.txt (line 18))
#   Using cached polars_runtime_32-1.34.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
# Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading ultralytics-8.3.218-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.7 MB/s  0:00:00
# Using cached ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Using cached polars-1.34.0-py3-none-any.whl (772 kB)
# Using cached polars_runtime_32-1.34.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.3 MB)
# Installing collected packages: polars-runtime-32, opencv-python, polars, ultralytics-thop, thop, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [ultralytics] [ultralytics]n]
# Successfully installed opencv-python-4.12.0.88 polars-1.34.0 polars-runtime-32-1.34.0 thop-0.1.1.post2209072238 ultralytics-8.3.218 ultralytics-thop-2.0.17

# %% [markdown]
# ## Initialize the model

# %%
import torch

model = torch.hub.load("ultralytics/yolov5", "yolov5s")
# Out:
# Using cache found in /home/jovyan/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-10-8 Python-3.12.11 torch-2.8.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB MIG 1g.10gb, 9728MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 112MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# Inference on images
img = "https://ultralytics.com/images/zidane.jpg"  # Can be a file, Path, PIL, OpenCV, numpy, or list of images

# Run inference
results = model(img)

# Display results
results.print()
results.show()
# Out:
# /home/jovyan/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 720x1280 2 persons, 1 tie, 1 cell phone
# Speed: 1076.6ms pre-process, 32.7ms inference, 70.3ms NMS per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
img = "../VLM-Try_around/images/Hase.png"
results = model(img)

results.print()
results.show()
# Out:
# /home/jovyan/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 1024x1024 2 persons, 1 tie
# Speed: 41.3ms pre-process, 33.2ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=1024x1024>
